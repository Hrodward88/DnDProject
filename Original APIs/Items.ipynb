# %%
import requests as req 
from bs4 import BeautifulSoup
import pandas as pd
import json
# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
# import random
# import re
# import scrapy

# %%
Itemsurl = 'https://zelda.fanapis.com/api/items'

# %%
Itemshtml = req.get(Itemsurl).json()
Itemshtml
# Out:
# {'success': True,
#  'count': 20,
#  'data': [{'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c0',
#     'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2b9'],
#    'name': '100th Ring',
#    'description': 'The 100th Ring is a recurring Item in The Legend of Zelda series. ',
#    'id': '5f6e9a9dfee1a5347127c76d'},
#   {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'],
#    'name': 'Ancient Arrow',
#    'description': 'Ancient Arrows are recurring Items in The Legend of Zelda series. ',
#    'id': '5f6e9a9dfee1a5347127c76f'},
#   {'games': [],
#    'name': 'Ancient Battle Axe',
#    'description': 'The Ancient Battle Axe are items in Breath of the Wild. ',
#    'id': '5f6e9a9dfee1a5347127c76e'},
#   {'games': [],
#    'name': 'Ambrosia Lite',
#    'description': 'Ambrosia Lite is an item in The Legend of Zelda comics by Valiant Comics. ',
#    'id': '5f6e9a9dfee1a5347127c770'},
#   {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c8'],
#    'name': 'Amber Tablet',
#    'description': 'The Amber Tablet is an item in Skyward Sword. ',
#    'id': '5f6e9a9dfee1a5347127c771'},
#   {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c8'],
#    'name': 'Amber Relic',
#    'description': 'Amber Relics are items in Skyward Sword. ',
#    'id': '5f6e9a9dfee1a5347127c772'},
#   {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'],
#    'name': 'Amber Earrings',
#    'description': 'The Amber Earrings are items in Breath of the Wild. ',
#    'id': '5f6e9a9dfee1a5347127c773'},
#   {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'],
#    'name': 'Ancient Spear',
#    'description': 'Ancient Spears are items in Breath of the Wild. ',
#    'id': '5f6e9a9dfee1a5347127c775'},
#   {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'],
#    'name': 'Ancient Soldier Gear',
#    'description': 'The Ancient Soldier Gear, also known as the Ancient Set, are recurring Items in The Legend of Zelda series. ',
#    'id': '5f6e9a9dfee1a5347127c776'},
#   {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'],
#    'name': 'Ancient Spring',
#    'description': 'Ancient Springs are items in Breath of the Wild. ',
#    'id': '5f6e9a9dfee1a5347127c774'},
#   {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2be'],
#    'name': 'Ancient Sky Book',
#    'description': 'The Ancient Sky Book is an item in Twilight Princess. ',
#    'id': '5f6e9a9dfee1a5347127c777'},
#   {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2cf'],
#    'name': 'Demon Blade',
#    'description': 'The Demon Blade is a class of Weapon used by Ghirahim in Hyrule Warriors. It is associated with Darkness. ',
#    'id': '5f6e9a9dfee1a5347127c77c'},
#   {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2ba',
#     'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c0',
#     'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c1',
#     'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2be',
#     'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c8'],
#    'name': 'Deku Seed',
#    'description': 'Deku Seeds, also known as Pumpkin Seeds, are recurring Items in The Legend of Zelda series. ',
#    'id': '5f6e9a9dfee1a5347127c781'},
#   {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'],
#    'name': 'Flint',
#    'description': 'Flints are items in Breath of the Wild. ',
#    'id': '5f6e9a9dfee1a5347127c77a'},
#   {'games': [],
#    'name': 'amiibo',
#    'description': 'amiibo is a line of near field communication devices available for the Nintendo 3DS, Wii U, and Nintendo Switch systems. They are figures or cards of Nintendo characters, as well as third-party characters that have appeared in Super Smash Bros. games. amiibo are scanned by tapping them on the Wii U GamePad, New Nintendo 3DS touch screen, on the NFC reader/writer for the original Nintendo 3DS, or on the Nintendo Switch right Joy-Con. ',
#    'id': '5f6e9a9dfee1a5347127c778'},
#   {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'],
#    'name': 'Dragonbone Boko Bat',
#    'description': 'Dragonbone Boko Bat are items in Breath of the Wild. ',
#    'id': '5f6e9a9dfee1a5347127c786'},
#   {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2bf'],
#    'name': 'Deluxe Picto Box',
#    'description': 'The Deluxe Picto Box is an item in The Wind Waker. ',
#    'id': '5f6e9a9dfee1a5347127c77d'},
#   {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2bf'],
#    'name': 'Delivery Bag',
#    'description': 'The Delivery Bag is an item in The Wind Waker. It is used for carrying an array of items. ',
#    'id': '5f6e9a9dfee1a5347127c77e'},
#   {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c8'],
#    'name': 'Eldin Roller',
#    'description': 'Eldin Rollers are items in Skyward Sword. ',
#    'id': '5f6e9a9dfee1a5347127c78b'},
#   {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c3',
#     'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c6'],
#    'name': 'Dog Food',
#    'description': 'The Dog Food, also known as Bottles of Dog Food and Canned Food, are recurring Items in The Legend of Zelda series. ',
#    'id': '5f6e9a9dfee1a5347127c783'}]}

# %%
len(Itemshtml['data'])
# Out:
# 20

# %%
Itemsdata = Itemshtml['data']
Itemsdata
# Out:
# [{'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c0',
#    'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2b9'],
#   'name': '100th Ring',
#   'description': 'The 100th Ring is a recurring Item in The Legend of Zelda series. ',
#   'id': '5f6e9a9dfee1a5347127c76d'},
#  {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'],
#   'name': 'Ancient Arrow',
#   'description': 'Ancient Arrows are recurring Items in The Legend of Zelda series. ',
#   'id': '5f6e9a9dfee1a5347127c76f'},
#  {'games': [],
#   'name': 'Ancient Battle Axe',
#   'description': 'The Ancient Battle Axe are items in Breath of the Wild. ',
#   'id': '5f6e9a9dfee1a5347127c76e'},
#  {'games': [],
#   'name': 'Ambrosia Lite',
#   'description': 'Ambrosia Lite is an item in The Legend of Zelda comics by Valiant Comics. ',
#   'id': '5f6e9a9dfee1a5347127c770'},
#  {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c8'],
#   'name': 'Amber Tablet',
#   'description': 'The Amber Tablet is an item in Skyward Sword. ',
#   'id': '5f6e9a9dfee1a5347127c771'},
#  {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c8'],
#   'name': 'Amber Relic',
#   'description': 'Amber Relics are items in Skyward Sword. ',
#   'id': '5f6e9a9dfee1a5347127c772'},
#  {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'],
#   'name': 'Amber Earrings',
#   'description': 'The Amber Earrings are items in Breath of the Wild. ',
#   'id': '5f6e9a9dfee1a5347127c773'},
#  {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'],
#   'name': 'Ancient Spear',
#   'description': 'Ancient Spears are items in Breath of the Wild. ',
#   'id': '5f6e9a9dfee1a5347127c775'},
#  {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'],
#   'name': 'Ancient Soldier Gear',
#   'description': 'The Ancient Soldier Gear, also known as the Ancient Set, are recurring Items in The Legend of Zelda series. ',
#   'id': '5f6e9a9dfee1a5347127c776'},
#  {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'],
#   'name': 'Ancient Spring',
#   'description': 'Ancient Springs are items in Breath of the Wild. ',
#   'id': '5f6e9a9dfee1a5347127c774'},
#  {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2be'],
#   'name': 'Ancient Sky Book',
#   'description': 'The Ancient Sky Book is an item in Twilight Princess. ',
#   'id': '5f6e9a9dfee1a5347127c777'},
#  {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2cf'],
#   'name': 'Demon Blade',
#   'description': 'The Demon Blade is a class of Weapon used by Ghirahim in Hyrule Warriors. It is associated with Darkness. ',
#   'id': '5f6e9a9dfee1a5347127c77c'},
#  {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2ba',
#    'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c0',
#    'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c1',
#    'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2be',
#    'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c8'],
#   'name': 'Deku Seed',
#   'description': 'Deku Seeds, also known as Pumpkin Seeds, are recurring Items in The Legend of Zelda series. ',
#   'id': '5f6e9a9dfee1a5347127c781'},
#  {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'],
#   'name': 'Flint',
#   'description': 'Flints are items in Breath of the Wild. ',
#   'id': '5f6e9a9dfee1a5347127c77a'},
#  {'games': [],
#   'name': 'amiibo',
#   'description': 'amiibo is a line of near field communication devices available for the Nintendo 3DS, Wii U, and Nintendo Switch systems. They are figures or cards of Nintendo characters, as well as third-party characters that have appeared in Super Smash Bros. games. amiibo are scanned by tapping them on the Wii U GamePad, New Nintendo 3DS touch screen, on the NFC reader/writer for the original Nintendo 3DS, or on the Nintendo Switch right Joy-Con. ',
#   'id': '5f6e9a9dfee1a5347127c778'},
#  {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'],
#   'name': 'Dragonbone Boko Bat',
#   'description': 'Dragonbone Boko Bat are items in Breath of the Wild. ',
#   'id': '5f6e9a9dfee1a5347127c786'},
#  {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2bf'],
#   'name': 'Deluxe Picto Box',
#   'description': 'The Deluxe Picto Box is an item in The Wind Waker. ',
#   'id': '5f6e9a9dfee1a5347127c77d'},
#  {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2bf'],
#   'name': 'Delivery Bag',
#   'description': 'The Delivery Bag is an item in The Wind Waker. It is used for carrying an array of items. ',
#   'id': '5f6e9a9dfee1a5347127c77e'},
#  {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c8'],
#   'name': 'Eldin Roller',
#   'description': 'Eldin Rollers are items in Skyward Sword. ',
#   'id': '5f6e9a9dfee1a5347127c78b'},
#  {'games': ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c3',
#    'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c6'],
#   'name': 'Dog Food',
#   'description': 'The Dog Food, also known as Bottles of Dog Food and Canned Food, are recurring Items in The Legend of Zelda series. ',
#   'id': '5f6e9a9dfee1a5347127c783'}]

# %%
values_by_key = {}

# Iterate over each dictionary in games_data
for dictionary in Itemsdata:
    # Iterate over each key-value pair in the dictionary
    for key, value in dictionary.items():
        # Check if the key is already in the values_by_key dictionary
        if key in values_by_key:
            # Append the value to the existing list of values for the key
            values_by_key[key].append(value)
        else:
            # Create a new list with the value for the key
            values_by_key[key] = [value]

# Print the values for each key
for key, values in values_by_key.items():
    print(f"{key}: {values}")
# Out:
# games: [['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c0', 'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2b9'], ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'], [], [], ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c8'], ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c8'], ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'], ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'], ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'], ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'], ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2be'], ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2cf'], ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2ba', 'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c0', 'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c1', 'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2be', 'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c8'], ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'], [], ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'], ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2bf'], ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2bf'], ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c8'], ['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c3', 'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c6']]
# name: ['100th Ring', 'Ancient Arrow', 'Ancient Battle Axe', 'Ambrosia Lite', 'Amber Tablet', 'Amber Relic', 'Amber Earrings', 'Ancient Spear', 'Ancient Soldier Gear', 'Ancient Spring', 'Ancient Sky Book', 'Demon Blade', 'Deku Seed', 'Flint', 'amiibo', 'Dragonbone Boko Bat', 'Deluxe Picto Box', 'Delivery Bag', 'Eldin Roller', 'Dog Food']
# description: ['The 100th Ring is a recurring Item in The Legend of Zelda series. ', 'Ancient Arrows are recurring Items in The Legend of Zelda series. ', 'The Ancient Battle Axe are items in Breath of the Wild. ', 'Ambrosia Lite is an item in The Legend of Zelda comics by Valiant Comics. ', 'The Amber Tablet is an item in Skyward Sword. ', 'Amber Relics are items in Skyward Sword. ', 'The Amber Earrings are items in Breath of the Wild. ', 'Ancient Spears are items in Breath of the Wild. ', 'The Ancient Soldier Gear, also known as the Ancient Set, are recurring Items in The Legend of Zelda series. ', 'Ancient Springs are items in Breath of the Wild. ', 'The Ancient Sky Book is an item in Twilight Princess. ', 'The Demon Blade is a class of Weapon used by Ghirahim in Hyrule Warriors. It is associated with Darkness. ', 'Deku Seeds, also known as Pumpkin Seeds, are recurring Items in The Legend of Zelda series. ', 'Flints are items in Breath of the Wild. ', 'amiibo is a line of near field communication devices available for the Nintendo 3DS, Wii U, and Nintendo Switch systems. They are figures or cards of Nintendo characters, as well as third-party characters that have appeared in Super Smash Bros. games. amiibo are scanned by tapping them on the Wii U GamePad, New Nintendo 3DS touch screen, on the NFC reader/writer for the original Nintendo 3DS, or on the Nintendo Switch right Joy-Con. ', 'Dragonbone Boko Bat are items in Breath of the Wild. ', 'The Deluxe Picto Box is an item in The Wind Waker. ', 'The Delivery Bag is an item in The Wind Waker. It is used for carrying an array of items. ', 'Eldin Rollers are items in Skyward Sword. ', 'The Dog Food, also known as Bottles of Dog Food and Canned Food, are recurring Items in The Legend of Zelda series. ']
# id: ['5f6e9a9dfee1a5347127c76d', '5f6e9a9dfee1a5347127c76f', '5f6e9a9dfee1a5347127c76e', '5f6e9a9dfee1a5347127c770', '5f6e9a9dfee1a5347127c771', '5f6e9a9dfee1a5347127c772', '5f6e9a9dfee1a5347127c773', '5f6e9a9dfee1a5347127c775', '5f6e9a9dfee1a5347127c776', '5f6e9a9dfee1a5347127c774', '5f6e9a9dfee1a5347127c777', '5f6e9a9dfee1a5347127c77c', '5f6e9a9dfee1a5347127c781', '5f6e9a9dfee1a5347127c77a', '5f6e9a9dfee1a5347127c778', '5f6e9a9dfee1a5347127c786', '5f6e9a9dfee1a5347127c77d', '5f6e9a9dfee1a5347127c77e', '5f6e9a9dfee1a5347127c78b', '5f6e9a9dfee1a5347127c783']

# %%
values_by_key['released_date']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 values_by_key['released_date']
#
# KeyError: 'released_date'

# %%
table_data = []

for dictionary in Itemsdata:
    row = list(dictionary.values())
    table_data.append(row)

# Print the table
for row in table_data:
    print(row)
# Out:
# [['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c0', 'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2b9'], '100th Ring', 'The 100th Ring is a recurring Item in The Legend of Zelda series. ', '5f6e9a9dfee1a5347127c76d']
# [['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'], 'Ancient Arrow', 'Ancient Arrows are recurring Items in The Legend of Zelda series. ', '5f6e9a9dfee1a5347127c76f']
# [[], 'Ancient Battle Axe', 'The Ancient Battle Axe are items in Breath of the Wild. ', '5f6e9a9dfee1a5347127c76e']
# [[], 'Ambrosia Lite', 'Ambrosia Lite is an item in The Legend of Zelda comics by Valiant Comics. ', '5f6e9a9dfee1a5347127c770']
# [['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c8'], 'Amber Tablet', 'The Amber Tablet is an item in Skyward Sword. ', '5f6e9a9dfee1a5347127c771']
# [['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c8'], 'Amber Relic', 'Amber Relics are items in Skyward Sword. ', '5f6e9a9dfee1a5347127c772']
# [['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'], 'Amber Earrings', 'The Amber Earrings are items in Breath of the Wild. ', '5f6e9a9dfee1a5347127c773']
# [['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'], 'Ancient Spear', 'Ancient Spears are items in Breath of the Wild. ', '5f6e9a9dfee1a5347127c775']
# [['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'], 'Ancient Soldier Gear', 'The Ancient Soldier Gear, also known as the Ancient Set, are recurring Items in The Legend of Zelda series. ', '5f6e9a9dfee1a5347127c776']
# [['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'], 'Ancient Spring', 'Ancient Springs are items in Breath of the Wild. ', '5f6e9a9dfee1a5347127c774']
# [['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2be'], 'Ancient Sky Book', 'The Ancient Sky Book is an item in Twilight Princess. ', '5f6e9a9dfee1a5347127c777']
# [['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2cf'], 'Demon Blade', 'The Demon Blade is a class of Weapon used by Ghirahim in Hyrule Warriors. It is associated with Darkness. ', '5f6e9a9dfee1a5347127c77c']
# [['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2ba', 'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c0', 'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c1', 'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2be', 'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c8'], 'Deku Seed', 'Deku Seeds, also known as Pumpkin Seeds, are recurring Items in The Legend of Zelda series. ', '5f6e9a9dfee1a5347127c781']
# [['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'], 'Flint', 'Flints are items in Breath of the Wild. ', '5f6e9a9dfee1a5347127c77a']
# [[], 'amiibo', 'amiibo is a line of near field communication devices available for the Nintendo 3DS, Wii U, and Nintendo Switch systems. They are figures or cards of Nintendo characters, as well as third-party characters that have appeared in Super Smash Bros. games. amiibo are scanned by tapping them on the Wii U GamePad, New Nintendo 3DS touch screen, on the NFC reader/writer for the original Nintendo 3DS, or on the Nintendo Switch right Joy-Con. ', '5f6e9a9dfee1a5347127c778']
# [['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c9'], 'Dragonbone Boko Bat', 'Dragonbone Boko Bat are items in Breath of the Wild. ', '5f6e9a9dfee1a5347127c786']
# [['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2bf'], 'Deluxe Picto Box', 'The Deluxe Picto Box is an item in The Wind Waker. ', '5f6e9a9dfee1a5347127c77d']
# [['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2bf'], 'Delivery Bag', 'The Delivery Bag is an item in The Wind Waker. It is used for carrying an array of items. ', '5f6e9a9dfee1a5347127c77e']
# [['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c8'], 'Eldin Roller', 'Eldin Rollers are items in Skyward Sword. ', '5f6e9a9dfee1a5347127c78b']
# [['https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c3', 'https://zelda.fanapis.com/api/games/5f6ce9d805615a85623ec2c6'], 'Dog Food', 'The Dog Food, also known as Bottles of Dog Food and Canned Food, are recurring Items in The Legend of Zelda series. ', '5f6e9a9dfee1a5347127c783']

# %%
for Game in Mondata:
    ata=dictionary['Games_data']
    values = Gamesdata.values

print(f"id: {id}, Name: {Name}, Description: {Description}, Developer: {Developer}, Publisher: {Publisher}, Release date: {Release_date}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 for Game in Mondata:
# ----> 2     Gamesdata=dictionary['Games_data']
#       3     values = Gamesdata.values
#       5 print(f"id: {id}, Name: {Name}, Description: {Description}, Developer: {Developer}, Publisher: {Publisher}, Release date: {Release_date}")
#
# KeyError: 'Games_data'

# %%
pd.DataFrame.from_records(Itemshtml['data'])
# Out:
#                                                 games                  name
# 0   [https://zelda.fanapis.com/api/games/5f6ce9d80...            100th Ring  \
# 1   [https://zelda.fanapis.com/api/games/5f6ce9d80...         Ancient Arrow
# 2                                                  []    Ancient Battle Axe
# 3                                                  []         Ambrosia Lite
# 4   [https://zelda.fanapis.com/api/games/5f6ce9d80...          Amber Tablet
# 5   [https://zelda.fanapis.com/api/games/5f6ce9d80...           Amber Relic
# 6   [https://zelda.fanapis.com/api/games/5f6ce9d80...        Amber Earrings
# 7   [https://zelda.fanapis.com/api/games/5f6ce9d80...         Ancient Spear
# 8   [https://zelda.fanapis.com/api/games/5f6ce9d80...  Ancient Soldier Gear
# 9   [https://zelda.fanapis.com/api/games/5f6ce9d80...        Ancient Spring
# 10  [https://zelda.fanapis.com/api/games/5f6ce9d80...      Ancient Sky Book
# 11  [https://zelda.fanapis.com/api/games/5f6ce9d80...           Demon Blade
# 12  [https://zelda.fanapis.com/api/games/5f6ce9d80...             Deku Seed
# 13  [https://zelda.fanapis.com/api/games/5f6ce9d80...                 Flint
# 14                                                 []                amiibo
# 15  [https://zelda.fanapis.com/api/games/5f6ce9d80...   Dragonbone Boko Bat
# 16  [https://zelda.fanapis.com/api/games/5f6ce9d80...      Deluxe Picto Box
# 17  [https://zelda.fanapis.com/api/games/5f6ce9d80...          Delivery Bag
# 18  [https://zelda.fanapis.com/api/games/5f6ce9d80...          Eldin Roller
# 19  [https://zelda.fanapis.com/api/games/5f6ce9d80...              Dog Food
#
#                                           description
# 0   The 100th Ring is a recurring Item in The Lege...  \
# 1   Ancient Arrows are recurring Items in The Lege...
# 2   The Ancient Battle Axe are items in Breath of ...
# 3   Ambrosia Lite is an item in The Legend of Zeld...
# 4      The Amber Tablet is an item in Skyward Sword.
# 5           Amber Relics are items in Skyward Sword.
# 6   The Amber Earrings are items in Breath of the ...
# 7    Ancient Spears are items in Breath of the Wild.
# 8   The Ancient Soldier Gear, also known as the An...
# 9   Ancient Springs are items in Breath of the Wild.
# 10  The Ancient Sky Book is an item in Twilight Pr...
# 11  The Demon Blade is a class of Weapon used by G...
# 12  Deku Seeds, also known as Pumpkin Seeds, are r...
# 13           Flints are items in Breath of the Wild.
# 14  amiibo is a line of near field communication d...
# 15  Dragonbone Boko Bat are items in Breath of the...
# 16  The Deluxe Picto Box is an item in The Wind Wa...
# 17  The Delivery Bag is an item in The Wind Waker....
# 18         Eldin Rollers are items in Skyward Sword.
# 19  The Dog Food, also known as Bottles of Dog Foo...
#
#                           id
# 0   5f6e9a9dfee1a5347127c76d
# 1   5f6e9a9dfee1a5347127c76f
# 2   5f6e9a9dfee1a5347127c76e
# 3   5f6e9a9dfee1a5347127c770
# 4   5f6e9a9dfee1a5347127c771
# 5   5f6e9a9dfee1a5347127c772
# 6   5f6e9a9dfee1a5347127c773
# 7   5f6e9a9dfee1a5347127c775
# 8   5f6e9a9dfee1a5347127c776
# 9   5f6e9a9dfee1a5347127c774
# 10  5f6e9a9dfee1a5347127c777
# 11  5f6e9a9dfee1a5347127c77c
# 12  5f6e9a9dfee1a5347127c781
# 13  5f6e9a9dfee1a5347127c77a
# 14  5f6e9a9dfee1a5347127c778
# 15  5f6e9a9dfee1a5347127c786
# 16  5f6e9a9dfee1a5347127c77d
# 17  5f6e9a9dfee1a5347127c77e
# 18  5f6e9a9dfee1a5347127c78b
# 19  5f6e9a9dfee1a5347127c783
